# %%
#import numpy library
import numpy as np

# %%
#import pandas library
import pandas as pd

# %%
#import matplotlib library pyplot folder
import matplotlib.pyplot as plt

# %%
#import seaborn library
import seaborn as sns

# %%
#csv type file access by pandas
test_data=pd.read_csv("Iris.csv")
test_data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
#value counting checking of "Species" in a DataFrame(test_data)
test_data["Species"].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
# Histogram in seaborn
sns.histplot(x=test_data["SepalLengthCm"])
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Count'>

# %%
# Histogram in seaborn
sns.histplot(data= test_data,x="SepalLengthCm",color="yellow") # data set stored in a variable(data) and x=column's data and colour=yellow
plt.title("Histogram for Sepal Length")
plt.show()

# %%
# Histogram in seaborn and kde with counts
sns.histplot(data= test_data,x="SepalLengthCm",color="green",kde=True) # Histogram with KDE of counts (kde=True)
plt.title("Histogram for Sepal Length")
plt.show()

# %%
# kde plot in seaborn
sns.kdeplot(data= test_data,x="SepalLengthCm",color="orange")
plt.title("Histogram for Sepal Length with KDE")
plt.show()

# %%
test_data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# Histogram in matplotlib
plt.hist(test_data.loc[test_data["Species"]=="Iris-setosa", "SepalLengthCm"], label="Iris-setosa")
plt.hist(test_data.loc[test_data["Species"] =="Iris-versicolor", "SepalLengthCm"], label = "Iris-versicolor")
plt.hist(test_data.loc[test_data["Species"] =="Iris-virginica", "SepalLengthCm"], label = "Iris-virginica")
plt.legend()
plt.show()

# %%
# Histogram in seaborn
sns.histplot(data=test_data,x="SepalLengthCm", hue="Species") # "Species" wise "SepalLengthCm" Histogram diagram
# plt.show() # without show
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Count'>

# %%
# Histogram in seaborn
sns.histplot(data=test_data,x="SepalLengthCm", hue="Species") # "Species" wise "SepalLengthCm" Histogram diagram
plt.show() # with show

# %%
# KDE in seaborn
sns.kdeplot(data=test_data,x="SepalLengthCm", hue="Species") # "Species" wise "SepalLengthCm" KDE diagram
# plt.show() # without show
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Density'>

# %%
# KDE in seaborn
sns.kdeplot(data=test_data,x="SepalLengthCm", hue="Species") # "Species" wise "SepalLengthCm" KDE diagram
plt.show() # with show

# %% [markdown]
# ## line and scatter plot

# %%
# line plot in seaborn
plt.figure(figsize=(5,5))
sns.lineplot(data=test_data,x="SepalLengthCm", y="PetalLengthCm") # not filttering data with "Species" category
plt.show()

# %%
# scatter plot in seaborn
plt.figure(figsize=(5,5))
sns.scatterplot(data = test_data, x = "SepalLengthCm", y="PetalLengthCm", hue="Species") # hue use for filttering data with "Species" category 
plt.show()

# %%
# line plot in seaborn and scatter plot in seaborn in single graph sheet
plt.figure(figsize=(10,5))

## line plot
plt.subplot(1,2,1)
sns.lineplot(data=test_data,x="SepalLengthCm", y="PetalLengthCm") # not filttering data with "Species" category

## scatter plot
plt.subplot(1,2,2)
sns.scatterplot(data = test_data, x = "SepalLengthCm", y="PetalLengthCm", hue="Species") # hue use for filttering data with "Species" category 
plt.show()

# %%
# line plot in seaborn and scatter plot in seaborn in single graph sheet
plt.figure(figsize=(10,5))

## line plot
plt.subplot(1,2,1)
sns.lineplot(data=test_data,x="SepalLengthCm", y="PetalLengthCm", hue="Species") # hue use not filttering data with "Species" category

## scatter plot
plt.subplot(1,2,2)
sns.scatterplot(data = test_data, x = "SepalLengthCm", y="PetalLengthCm", hue="Species") # hue use for filttering data with "Species" category 
plt.show()

# %%
test_data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
# co-relation in seaborn
test_data[["SepalLengthCm","SepalWidthCm","PetalLengthCm","PetalWidthCm"]].corr() # corr() is co-relation inbuild python function
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
# heatmap of co-relation in seaborn
sns.heatmap(test_data[["SepalLengthCm","SepalWidthCm","PetalLengthCm","PetalWidthCm"]].corr(),annot=True)
# Out:
# <Axes: >

# %%
test_data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
# countplot in seaborn of "Species" in a DataFrame(test_data)
sns.countplot(data=test_data,x="Species")
# Out:
# <Axes: xlabel='Species', ylabel='count'>

# %%
# countplot in seaborn of "Species" in a DataFrame(test_data)
sns.countplot(data=test_data,x="Species",palette=["red","yellow","blue"]) # palette is used to giving colour
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_16840\3389155382.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=test_data,x="Species",palette=["red","yellow","blue"])

# %%
# countplot in seaborn of "Species" in a DataFrame(test_data) and use here as hue
sns.countplot(data=test_data,x="Species",hue="Species",palette=["red","yellow","blue"]) # palette is used to giving colour
plt.show()

# %%
test_data["Species"].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# ## Bar plot

# %%
# calculating mean of "SepalLengthCm" in each "Species" in a DataFrame(test_data)
data_1=test_data.loc[test_data["Species"]=="Iris-setosa","SepalLengthCm"].mean() # mean of "SepalLengthCm" for "Iris-setosa" category
data_2=test_data.loc[test_data["Species"]=="Iris-versicolor","SepalLengthCm"].mean() # mean of "SepalLengthCm" for "Iris-versicolor" category
data_3=test_data.loc[test_data["Species"]=="Iris-virginica","SepalLengthCm"].mean() # mean of "SepalLengthCm" for "Iris-virginica" category
print(data_1,data_2,data_3) # mean printing
# Out:
# 5.006 5.936 6.587999999999998

# %%
# barplot in seaborn calculating mean of "Species" in a DataFrame(test_data)
sns.barplot(data=test_data, x="Species",y="SepalLengthCm")# mean of "SepalLengthCm" in each "Species" category
# Out:
# <Axes: xlabel='Species', ylabel='SepalLengthCm'>

# %%
# max , min, mean of "SepalLengthCm" of whole DataFrame(test_data)
test_data["SepalLengthCm"].min(),test_data["SepalLengthCm"].max(),test_data["SepalLengthCm"].mean()
# Out:
# (4.3, 7.9, 5.843333333333334)

# %%
test_data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# mediann of "SepalLengthCm" of each "Species" of the DataFrame(test_data) using group by function
test_data.groupby("Species")["SepalLengthCm"].median().reset_index() # using group by function
# Out:
#            Species  SepalLengthCm
# 0      Iris-setosa            5.0
# 1  Iris-versicolor            5.9
# 2   Iris-virginica            6.5

# %%
# median of "SepalLengthCm" of each "Species" of the DataFrame(test_data)  in bar plot
sns.barplot(data=test_data,x="Species",y="SepalLengthCm",estimator="median") # show in bar plot using (estimator ="median")
plt.show()

# %%
# median of "SepalLengthCm" of each "Species" of the DataFrame(test_data) in bar plot
group_data = test_data.groupby("Species")["SepalLengthCm"].median().reset_index() # median of "SepalLengthCm" of each "Species" stored in group_data variable
sns.barplot(data = group_data, x = "Species", y="SepalLengthCm")
plt.show()

# %% [markdown]
# ## Box Plot

# %%
# describe function
test_data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
# box plot for "SepalWidthCm" Category in the DataFrame(test_data)
sns.boxplot(data=test_data,y="SepalWidthCm", ) # here we checking outlier points(Anomaly)
# Out:
# <Axes: ylabel='SepalWidthCm'>

# %%
#box plot for each "Species" of "SepalWidthCm" Category in the DataFrame(df)
sns.boxplot(data=test_data,x='Species',y="SepalWidthCm") # here we checking outlier points(Anomaly)
# Out:
# <Axes: xlabel='Species', ylabel='SepalWidthCm'>

# %% [raw]
# # Pokémon Dataset Exploratory Data Analysis (EDA) Questions
#
# ## Basic Statistics and Distribution
# 1. What are the mean, median, and standard deviation of the HP, Attack, Defense, Sp. Atk, Sp. Def, and Speed attributes?
# 2. How are the Pokémon distributed across the different generations?
#
# ## Type Analysis
# 3. What are the most common primary and secondary types of Pokémon?
# 4. Are there any types that are more likely to be Legendary?
#
# ## Correlations
# 5. What are the correlations between different attributes (e.g., HP, Attack, Defense, etc.)?
# 6. Is there a correlation between a Pokémon's type and its stats?
#
# ## Speed Analysis
# 7. What is the distribution of Pokémon across different speed categories (slow, low speed, medium speed)?
# 8. How does speed vary by generation?
#
# ## Type Combinations
# 9. What are the most and least common type combinations?
# 10. Do certain type combinations tend to have higher stats?
#
# ## Generation Comparisons
# 11. How do the stats of Pokémon vary across different generations?
# 12. Are certain generations more likely to have Pokémon with higher Attack or Defense stats?
#
# ## Type Effectiveness
# 13. Are there any noticeable trends in the types of Pokémon that are more likely to have higher or lower Speed?
# 14. How do dual-type Pokémon compare to single-type Pokémon in terms of stats?
#
# ## Attribute Distribution
# 15. What is the distribution of each stat (HP, Attack, Defense, Sp. Atk, Sp. Def, Speed) across the dataset?
# 16. Are there any outliers or particularly strong/weak Pokémon for each stat?
#
# ## Missing Values
# 17. Are there any missing values in the dataset?
# 18. How can the missing values be handled or imputed?

# %%
#csv type file access by pandas
test_data_1=pd.read_csv("pokemon_data.csv")
test_data_1
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
test_data_1.loc[:,"Attack":"Speed"].describe()
# Out:
#            Attack     Defense     Sp. Atk     Sp. Def       Speed
# count  800.000000  800.000000  800.000000  800.000000  800.000000
# mean    79.001250   73.842500   72.820000   71.902500   68.277500
# std     32.457366   31.183501   32.722294   27.828916   29.060474
# min      5.000000    5.000000   10.000000   20.000000    5.000000
# 25%     55.000000   50.000000   49.750000   50.000000   45.000000
# 50%     75.000000   70.000000   65.000000   70.000000   65.000000
# 75%    100.000000   90.000000   95.000000   90.000000   90.000000
# max    190.000000  230.000000  194.000000  230.000000  180.000000

# %%
## Basic Statistics and Distribution
# 1. What are the mean, median, and standard deviation of the HP, Attack, Defense, Sp. Atk, Sp. Def, and Speed attributes?

# mean of the HP, Attack, Defense, Sp. Atk, Sp. Def, and Speed attributes in a DataFrame(test_data_1)
test_data_1.loc[:,"HP":"Speed"].mean()
# Out:
# HP         69.25875
# Attack     79.00125
# Defense    73.84250
# Sp. Atk    72.82000
# Sp. Def    71.90250
# Speed      68.27750
# dtype: float64

# %%
# median of the HP, Attack, Defense, Sp. Atk, Sp. Def, and Speed attributes in a DataFrame(test_data_1)
test_data_1.loc[:,"HP":"Speed"].median()
# Out:
# HP         65.0
# Attack     75.0
# Defense    70.0
# Sp. Atk    65.0
# Sp. Def    70.0
# Speed      65.0
# dtype: float64

# %%
# std of the HP, Attack, Defense, Sp. Atk, Sp. Def, and Speed attributes in a DataFrame(test_data_1)
test_data_1.loc[:,"HP":"Speed"].std()
# Out:
# HP         25.534669
# Attack     32.457366
# Defense    31.183501
# Sp. Atk    32.722294
# Sp. Def    27.828916
# Speed      29.060474
# dtype: float64

# %%
deepjoy=test_data_1.loc[:,"HP":"Speed"].mean()
deepjoy
# Out:
# HP         69.25875
# Attack     79.00125
# Defense    73.84250
# Sp. Atk    72.82000
# Sp. Def    71.90250
# Speed      68.27750
# dtype: float64

# %%
saikat=test_data_1.loc[:,"HP":"Speed"].median()
saikat
# Out:
# HP         65.0
# Attack     75.0
# Defense    70.0
# Sp. Atk    65.0
# Sp. Def    70.0
# Speed      65.0
# dtype: float64

# %%
debraj=test_data_1.loc[:,"HP":"Speed"].std()
debraj
# Out:
# HP         25.534669
# Attack     32.457366
# Defense    31.183501
# Sp. Atk    32.722294
# Sp. Def    27.828916
# Speed      29.060474
# dtype: float64

# %%
# Bar Graph
plt.figure(figsize=(20,5))

plt.subplot(1,3,1)
x1 = ["HP", "Attack", "Defense", "Sp. Atk", "Sp. Def", "Speed"]
y1 = test_data_1.loc[:,"HP":"Speed"].mean()
plt.bar(x1, y1, label='First Bars',color="blue")
plt.xlabel('Category')
plt.ylabel('values')
plt.title('Mean Bar Graph')
plt.legend()

plt.subplot(1,3,2)
x2 = ["HP", "Attack", "Defense", "Sp. Atk", "Sp. Def", "Speed"]
y2 = test_data_1.loc[:,"HP":"Speed"].median()
plt.bar(x2, y2, label='Second Bars',color="green")
plt.xlabel('Category')
plt.ylabel('Values')
plt.title('Median Bar Graph')
plt.legend()

plt.subplot(1,3,3)
x3 = ["HP", "Attack", "Defense", "Sp. Atk", "Sp. Def", "Speed"]
y3 = test_data_1.loc[:,"HP":"Speed"].std()
plt.bar(x3, y3, label='Third Bars',color="orange")
plt.xlabel('Category')
plt.ylabel('Values')
plt.title('Standard Deviation Bar Graph')
plt.legend()

plt.show()

# %%
# type, category, value
# mean, hp, 69.258750
# mean, attack, 79.001250

# %%
# Line Graph
x = ["HP", "Attack", "Defense", "Sp. Atk", "Sp. Def", "Speed"]
y1 = test_data_1.loc[:,"HP":"Speed"].mean()
y2 = test_data_1.loc[:,"HP":"Speed"].median()
y3 = test_data_1.loc[:,"HP":"Speed"].std()

plt.figure(figsize=(10,4))
plt.plot(x,y1,color="blue",label = "Mean", marker='s', linestyle='dashdot')
plt.plot(x,y2,color="yellow" ,label = "Median", marker='o', linestyle='dashed')
plt.plot(x,y3,color="green" ,label = "Standard Deviation", marker='d')
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.title("Line Plot")
plt.legend()
plt.show()
